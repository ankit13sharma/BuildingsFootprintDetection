# %%
from osgeo import gdal

import numpy as np

import h5py
import random
from scipy import ndarray
from skimage import exposure

from random import random as rd
import cv2 as cv

from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras import applications
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from keras.losses import binary_crossentropy as bce
from keras.losses import categorical_crossentropy as cce
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping #,TensorBoard#, ReduceLROnPlateau, LearningRateScheduler
from keras.utils.np_utils import to_categorical  
import utils as utils
import predict as predict
# Out:
# Using TensorFlow backend.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
K.clear_session()

# %%
def image_generator(image_path,label_path,image_id,tile_id,y_coord,x_coord, batch,isAugment=False):
    
    def raster2arr(raster, bnd,x,y,wndo):
        rr = np.zeros((wndo, wndo, bnd))
        newValue = 0
        for b in range(bnd):
            band = raster.GetRasterBand(b+1)
            img = band.ReadAsArray(x, y, wndo, wndo)
            noDataValue = band.GetNoDataValue()
            img[img == noDataValue] = newValue
            rr[:,:,b] = img
        return rr.astype(np.uint8)
    
    def com_gen(image,label,isAugment):
        K.set_image_data_format('channels_last')
        def combine_generator(gen1, gen2):
            while True:
                yield(gen1.next(), gen2.next())
        
        if isAugment is True:
            data_gen_args = dict(horizontal_flip=True,
                             vertical_flip=True,
                             rotation_range=45,
                             width_shift_range=0.2,
                             height_shift_range=0.2,
#                              brightness_range=[0.8,1.2],
                             zoom_range=0.2,
                             fill_mode='nearest',
                             data_format = "channels_last",
                             rescale = 1./255)
        else:
            data_gen_args = dict(data_format = "channels_last",
                                 rescale = 1./255)
        
        image_datagen = ImageDataGenerator(**data_gen_args)
        mask_datagen = ImageDataGenerator(**data_gen_args)
        image_datagen.fit(image, augment=isAugment, rounds=1, seed=42)
        mask_datagen.fit(label, augment=isAugment, rounds=1, seed=42)
        image_generator = image_datagen.flow(image, batch_size=1, seed=42)
        mask_generator = mask_datagen.flow(label, batch_size=1, seed=42)
        
        return combine_generator(image_generator,mask_generator)

    
    total_images = len(y_coord)
    all_images_id =list(range(total_images))
    random.seed(948)
    random.shuffle(all_images_id)
    
    current_image_id = 0
    while (current_image_id<total_images):
        
        random.shuffle(all_images_id)
        
        batch_input = np.zeros((batch,size,size,3))
        batch_output = np.zeros((batch,size,size,1))
        
       
        for batch_index in range(batch):
            index = all_images_id[current_image_id]
            x = x_coord[index]
            y = y_coord[index]
            img_id = image_id[index]
            
        
            raster = gdal.Open(image_path[img_id])
            batch_input[batch_index,:,:,:] = raster2arr(raster,3,x,y,size)
            raster = None
            
            raster = gdal.Open(label_path[img_id])
            batch_output[batch_index,:,:,:]= raster2arr(raster,1,x,y,size)*255
            raster = None  
            
        current_image_id += 1
        return (com_gen(batch_input, batch_output,isAugment))

def dev_test_generator(image_path,label_path,image_id,tile_id,y_coord,x_coord, batch):    
    
    def raster2arr(raster, bnd,x,y,wndo):
        rr = np.zeros((wndo, wndo, bnd))
        newValue = 0
        for b in range(bnd):
            band = raster.GetRasterBand(b+1)
            img = band.ReadAsArray(x, y, wndo, wndo)
            noDataValue = band.GetNoDataValue()
            img[img == noDataValue] = newValue
            rr[:,:,b] = img
        return rr.astype(np.uint8)

    def com_gen(image2,label2):
        K.set_image_data_format('channels_last')
        def combine_generator(gen1, gen2):
            while True:
                yield(gen1.next(), gen2.next())                                   
  
        data_gen_args2 = dict(data_format = "channels_last",
                             rescale = 1./255)
        image_datagen2 = ImageDataGenerator(**data_gen_args2)
        mask_datagen2 = ImageDataGenerator(**data_gen_args2)
        #image_datagen.fit(image, augment=True, rounds=5, seed=42)
        #mask_datagen.fit(label, augment=True, rounds=5, seed=42)
        image_generator2 = image_datagen2.flow(image2, batch_size=1, seed=56)
        mask_generator2 = mask_datagen2.flow(label2, batch_size=1, seed=56)
        val_generator = combine_generator(image_generator2,mask_generator2)
        return val_generator
    
    total_images = len(y_coord)
    all_images_id =list(range(total_images))
    random.seed(948)
    random.shuffle(all_images_id)
    
    current_image_id = 0
    while (current_image_id<total_images):
        
        random.shuffle(all_images_id)
        
        batch_input = np.zeros((batch,size,size,3))
        batch_output = np.zeros((batch,size,size,1))
        
       
        for batch_index in range(batch):
            index = all_images_id[current_image_id]
            x = x_coord[index]
            y = y_coord[index]
            img_id = image_id[index]
            
        
            raster = gdal.Open(image_path[img_id])
            batch_input[batch_index,:,:,:] = raster2arr(raster,3,x,y,size)
            raster = None
            
            raster = gdal.Open(label_path[img_id])
            batch_output[batch_index,:,:,:]= raster2arr(raster,1,x,y,size)*255
            raster = None  
            
        current_image_id += 1
        return (com_gen(batch_input, batch_output))

# %%
size = 256
def unet(size, lri, input_height = size, input_width = size, nClasses = 1):

    K.set_image_data_format('channels_last')
    
    input_size = (input_width, input_height, 3)
    input1 = Input(shape = input_size)
    n = 64
    drate1 = 0.5
    drate2 = 0.5
    drate3 = 0.5
    drate4 = 0.5
    drate5 = 0.5
    lmbd = 0.0001
    #bn01 = ( BatchNormalization())(input1) 
    
    #drop0 = Dropout(0)(input1)
    conv1 = Conv2D(n, (3,3), kernel_regularizer=l2(lmbd), activation = 'relu', padding = 'same', data_format= "channels_last", kernel_initializer = 'he_normal')(input1)
    drop1 = Dropout(drate1)(conv1)
    bn11 = ( BatchNormalization())(drop1) 

    conv1 = Conv2D(n, (3,3), kernel_regularizer=l2(lmbd), activation = 'relu', padding = 'same', data_format= "channels_last", kernel_initializer = 'he_normal')(bn11)
    drop12 = Dropout(drate2)(conv1)
    bn12 = ( BatchNormalization())(drop12) 

    pool1 = MaxPooling2D(pool_size=(2, 2))(bn12)
    
    conv2 = Conv2D(n*2, (3,3), kernel_regularizer=l2(lmbd), activation = 'relu', padding = 'same',  data_format= "channels_last", kernel_initializer = 'he_normal')(pool1)
    drop2 = Dropout(drate1)(conv2) 
    bn21 = ( BatchNormalization())(drop2)

    conv2 = Conv2D(n*2, (3,3), kernel_regularizer=l2(lmbd), activation = 'relu', padding = 'same',  data_format= "channels_last", kernel_initializer = 'he_normal')(bn21)
    drop22 = Dropout(drate2)(conv2)  
    bn22 = ( BatchNormalization())(drop22)   
    
    pool2 = MaxPooling2D(pool_size=(2, 2))(bn22)
    
    conv3 = Conv2D(n*4, (3,3), kernel_regularizer=l2(lmbd), activation = 'relu', padding = 'same', data_format= "channels_last", kernel_initializer = 'he_normal')(pool2)
    drop3 = Dropout(drate1)(conv3)
    bn31 = ( BatchNormalization())(drop3)

    conv3 = Conv2D(n*4, (3,3), kernel_regularizer=l2(lmbd), activation = 'relu', padding = 'same', data_format= "channels_last", kernel_initializer ='he_normal')(bn31)
    drop32 = Dropout(drate2)(conv3)
    bn32 = ( BatchNormalization())(drop32) 
    
    pool3 = MaxPooling2D(pool_size=(2, 2))(bn32)
    
    conv4 = Conv2D(n*8, (3,3), kernel_regularizer=l2(lmbd), activation = 'relu', padding = 'same', data_format= "channels_last", kernel_initializer ='he_normal')(pool3)
    drop4 = Dropout(drate1)(conv4)
    bn41 = ( BatchNormalization())(drop4) 

    conv4 = Conv2D(n*8, (3,3), kernel_regularizer=l2(lmbd), activation = 'relu', padding = 'same', data_format= "channels_last", kernel_initializer ='he_normal')(bn41)
    drop42 = Dropout(drate5)(conv4)
    bn42 = ( BatchNormalization())(drop42) 
    
    pool4 = MaxPooling2D(pool_size=(2, 2))(bn42)
   
    conv5 = Conv2D(n*16, (3,3), kernel_regularizer=l2(lmbd), activation = 'relu', padding = 'same', data_format= "channels_last", kernel_initializer ='he_normal')(pool4)
    drop5 = Dropout(drate5)(conv5)
    bn51 = ( BatchNormalization())(drop5) 
    conv5 = Conv2D(n*16, (3,3), kernel_regularizer=l2(lmbd), activation = 'relu', padding = 'same', data_format= "channels_last", kernel_initializer ='he_normal')(bn51)
    drop52 = Dropout(drate4)(conv5)
    bn52 = ( BatchNormalization())(drop52) 
    
    up6 = Conv2D(n*8, (2,2), kernel_regularizer=l2(lmbd), activation = 'relu', padding = 'same',data_format= "channels_last",  kernel_initializer ='he_normal')(UpSampling2D(size = (2,2))(bn52))
    merge6 = concatenate([bn42,up6], axis = 3)
    #merge6 = concatenate([conv4,up6], axis = 3)
    
    conv6 = Conv2D(n*8, (3,3), kernel_regularizer=l2(lmbd), activation = 'relu', padding = 'same', data_format= "channels_last", kernel_initializer ='he_normal')(merge6)
    drop6 = Dropout(drate3)(conv6)
    bn61 = ( BatchNormalization())(drop6) 

    conv6 = Conv2D(n*8, (3,3), kernel_regularizer=l2(lmbd), activation = 'relu', padding = 'same', data_format= "channels_last", kernel_initializer ='he_normal')(bn61)
    drop62 = Dropout(drate4)(conv6)
    bn62 = ( BatchNormalization())(drop62) 
    
    up7 = Conv2D(n*4, (2,2), kernel_regularizer=l2(lmbd), activation = 'relu', padding = 'same', data_format= "channels_last", kernel_initializer ='he_normal')(UpSampling2D(size = (2,2))(bn62))
    
    merge7 = concatenate([bn32,up7], axis = 3)
    
    
    conv7 = Conv2D(n*4, (3,3), kernel_regularizer=l2(lmbd), activation = 'relu', padding = 'same', data_format= "channels_last", kernel_initializer ='he_normal')(merge7)
    drop7 = Dropout(drate3)(conv7)
    bn71 = ( BatchNormalization())(drop7) 

    conv7 = Conv2D(n*4, (3,3), kernel_regularizer=l2(lmbd), activation = 'relu', padding = 'same', data_format= "channels_last", kernel_initializer ='he_normal')(bn71)
    drop72 = Dropout(drate4)(conv7)
    bn72 = ( BatchNormalization())(drop72) 
    

    up8 = Conv2D(n*2, (2,2), kernel_regularizer=l2(lmbd), activation = 'relu', padding = 'same', data_format= "channels_last", kernel_initializer ='he_normal')(UpSampling2D(size = (2,2))(bn72))
    
    
    merge8 = concatenate([bn22,up8], axis = 3)
    
    conv8 = Conv2D(n*2, (3,3), kernel_regularizer=l2(lmbd), activation = 'relu', padding = 'same', data_format= "channels_last", kernel_initializer ='he_normal')(merge8)
    drop8 = Dropout(drate3)(conv8)
    bn81 = ( BatchNormalization())(drop8) 

    conv8 = Conv2D(n*2, (3,3), kernel_regularizer=l2(lmbd), activation = 'relu', padding = 'same', data_format= "channels_last", kernel_initializer ='he_normal')(bn81)
    drop82 = Dropout(drate4)(conv8)
    bn82 = ( BatchNormalization())(drop82) 
    
    up9 = Conv2D(n, (2,2), kernel_regularizer=l2(lmbd), activation = 'relu', padding = 'same', data_format= "channels_last", kernel_initializer ='he_normal')(UpSampling2D(size = (2,2))(bn82))
    merge9 = concatenate([bn12,up9], axis = 3)
    
    conv9 = Conv2D(n, (3,3), kernel_regularizer=l2(lmbd), activation = 'relu', padding = 'same', data_format= "channels_last", kernel_initializer ='he_normal')(merge9)
    drop9 = Dropout(drate3)(conv9)
    bn91 = ( BatchNormalization())(drop9) 

    conv9 = Conv2D(n, (3,3), kernel_regularizer=l2(lmbd), activation = 'relu', padding = 'same', data_format= "channels_last", kernel_initializer ='he_normal')(bn91)
    drop92 = Dropout(drate4)(conv9)
    bn92 = ( BatchNormalization())(drop92) 
    
    conv10 = Conv2D(nClasses, (1,1), kernel_regularizer=l2(lmbd), activation = 'sigmoid', padding = 'same', data_format= "channels_last", kernel_initializer ='he_normal')(bn92)
    model = Model(inputs = input1, outputs = conv10)
    
    model.compile(optimizer = Adam(lr  = lri), loss= utils.dice_loss, metrics = [utils.iou, utils.dice])
   
    return model

# %%
filepath1 = './images'
filepath2 = './labels_old'

size = 256
#List of all jps and tif files
ipath = ((utils.get_all_images(filepath1, 'jpg')))
cpath = ((utils.get_all_images(filepath2, 'tif')))

assert len(ipath) == len(cpath)

ipath_train, ipath_val, cpath_train, cpath_val = train_test_split(ipath,cpath, train_size = 0.6, random_state=64, shuffle = True)
ipath_dev, ipath_test, cpath_dev, cpath_test = train_test_split(ipath_val,cpath_val, train_size = 0.5, random_state=128, shuffle = True)

# %%
def fetch_tiles_info(ipath):
    img_id  = []
    tile_id = []
    y_coord = []
    x_coord = []


    for i in range(len(ipath)):
        img_id,tile_id,y_coord,x_coord = utils.apply_fetch_all_tiles(ipath[i],img_id,tile_id,y_coord,x_coord,1,i)
        
#         img_id,tile_id,y_coord,x_coord = utils.apply_fetch_tiles_at_random(ipath[i],img_id,tile_id,y_coord,x_coord,len(img_id),len(img_id),i)
    
    return img_id,tile_id,y_coord,x_coord

# %%
img_id_train,tile_id_train,y_coord_train,x_coord_train = fetch_tiles_info(ipath_train)
img_id_train,tile_id_train,y_coord_train,x_coord_train = utils.shuffle_list(img_id_train,tile_id_train,y_coord_train,x_coord_train)

img_id_dev,tile_id_dev,y_coord_dev,x_coord_dev = fetch_tiles_info(ipath_dev)
img_id_dev,tile_id_dev,y_coord_dev,x_coord_dev = utils.shuffle_list(img_id_dev,tile_id_dev,y_coord_dev,x_coord_dev)

img_id_test,tile_id_test,y_coord_test,x_coord_test = fetch_tiles_info(ipath_test)
img_id_test,tile_id_test,y_coord_test,x_coord_test = utils.shuffle_list(img_id_test,tile_id_test,y_coord_test,x_coord_test)
# Out:
# image: 0, number of tiles: 1
# image: 1, number of tiles: 1
# image: 2, number of tiles: 1
# image: 3, number of tiles: 1
# image: 4, number of tiles: 1
# image: 5, number of tiles: 1
# image: 6, number of tiles: 1
# image: 7, number of tiles: 1
# image: 8, number of tiles: 1
# image: 9, number of tiles: 1
# image: 10, number of tiles: 1
# image: 11, number of tiles: 1
# image: 12, number of tiles: 1
# image: 13, number of tiles: 1
# image: 14, number of tiles: 1
# image: 15, number of tiles: 1
# image: 16, number of tiles: 1
# image: 17, number of tiles: 1
# image: 18, number of tiles: 1
# image: 19, number of tiles: 1
# image: 20, number of tiles: 1
# image: 21, number of tiles: 1
# image: 22, number of tiles: 1
# image: 23, number of tiles: 1
# image: 24, number of tiles: 1
# image: 25, number of tiles: 1
# image: 26, number of tiles: 1
# image: 27, number of tiles: 1
# image: 28, number of tiles: 1
# image: 29, number of tiles: 1
# image: 30, number of tiles: 1
# image: 31, number of tiles: 1
# image: 0, number of tiles: 1
# image: 1, number of tiles: 1
# image: 2, number of tiles: 1
# image: 3, number of tiles: 1
# image: 4, number of tiles: 1
# image: 5, number of tiles: 1
# image: 6, number of tiles: 1
# image: 7, number of tiles: 1
# image: 8, number of tiles: 1
# image: 9, number of tiles: 1
# image: 10, number of tiles: 1
# image: 0, number of tiles: 1
# image: 1, number of tiles: 1
# image: 2, number of tiles: 1
# image: 3, number of tiles: 1
# image: 4, number of tiles: 1
# image: 5, number of tiles: 1
# image: 6, number of tiles: 1
# image: 7, number of tiles: 1
# image: 8, number of tiles: 1
# image: 9, number of tiles: 1
# image: 10, number of tiles: 1

# %%
batch = 8

train_generator = image_generator(ipath_train,cpath_train,img_id_train,tile_id_train,y_coord_train,x_coord_train, batch)

val_generator = image_generator(ipath_dev,cpath_dev,img_id_dev,tile_id_dev,y_coord_dev,x_coord_dev, 1)

# %%
def training(size):
    K.clear_session()
             
    K.set_image_data_format('channels_last')
    seed = 23
    np.random.seed(seed)
    tf.compat.v1.set_random_seed(seed)
    lri = 1e-3

    model = unet(size, lri)
    model.summary()
    
    checkpoint = ModelCheckpoint("./model_1.h5", monitor='val_dice', verbose=1, save_best_only=True, save_weights_only=False, mode='max', peroid=1)
    
    early = EarlyStopping(monitor='val_dice', min_delta=0, patience=20, verbose=1, mode='auto')
    history = model.fit(train_generator, steps_per_epoch = (len(y_coord_train)//batch), epochs = 50 ,verbose = 2, callbacks = [checkpoint, early], validation_data= val_generator, validation_steps = (len(y_coord_dev)))    
    

training(size)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 256, 256, 64) 0           conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 64) 256         dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 64) 36928       batch_normalization[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256, 256, 64) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256, 256, 64) 256         dropout_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 64) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 128 73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 128, 128, 128 0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 128, 128 512         dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 128 147584      batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 128, 128, 128 0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128, 128, 128 512         dropout_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 256)  295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 64, 64, 256)  0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 64, 256)  1024        dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 256)  590080      batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 64, 64, 256)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 64, 64, 256)  1024        dropout_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 256)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 512)  1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 32, 32, 512)  0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 512)  2048        dropout_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 512)  2359808     batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 32, 32, 512)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 512)  2048        dropout_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 512)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 1024) 4719616     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 16, 16, 1024) 0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 1024) 4096        dropout_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 1024) 9438208     batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 16, 16, 1024) 0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 1024) 4096        dropout_9[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 32, 32, 1024) 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 512)  2097664     up_sampling2d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 1024) 0           batch_normalization_7[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 512)  4719104     concatenate[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 32, 32, 512)  0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 32, 32, 512)  2048        dropout_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 512)  2359808     batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 32, 32, 512)  0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 32, 32, 512)  2048        dropout_11[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 64, 64, 512)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 256)  524544      up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 512)  0           batch_normalization_5[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 256)  1179904     concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 64, 64, 256)  0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 64, 64, 256)  1024        dropout_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 256)  590080      batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 64, 64, 256)  0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 64, 64, 256)  1024        dropout_13[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 128, 128, 256 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 128, 128, 128 131200      up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 256 0           batch_normalization_3[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 128, 128, 128 295040      concatenate_2[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 128, 128, 128 0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 128, 128, 128 512         dropout_14[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 128, 128, 128 147584      batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 128, 128, 128 0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 128, 128, 128 512         dropout_15[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 256, 256, 128 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 256, 256, 64) 32832       up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 128 0           batch_normalization_1[0][0]
#                                                                  conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 256, 256, 64) 73792       concatenate_3[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 256, 256, 64) 0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 256, 256, 64) 256         dropout_16[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 256, 256, 64) 36928       batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 256, 256, 64) 0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 256, 256, 64) 256         dropout_17[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 256, 256, 1)  65          batch_normalization_17[0][0]
# ==================================================================================================
# Total params: 31,055,297
# Trainable params: 31,043,521
# Non-trainable params: 11,776
# __________________________________________________________________________________________________
# Epoch 1/50
#
# Epoch 00001: val_dice improved from -inf to 0.34804, saving model to ./model_1.h5
# 4/4 - 26s - loss: 2.0519 - iou: 0.1790 - dice: 0.3033 - val_loss: 1.9841 - val_iou: 0.2107 - val_dice: 0.3480
# Epoch 2/50
#
# Epoch 00002: val_dice improved from 0.34804 to 0.35167, saving model to ./model_1.h5
# 4/4 - 14s - loss: 1.9148 - iou: 0.2554 - dice: 0.4063 - val_loss: 1.9530 - val_iou: 0.2134 - val_dice: 0.3517
# Epoch 3/50
#
# Epoch 00003: val_dice improved from 0.35167 to 0.38800, saving model to ./model_1.h5
# 4/4 - 14s - loss: 1.7753 - iou: 0.3524 - dice: 0.5208 - val_loss: 1.8939 - val_iou: 0.2407 - val_dice: 0.3880
# Epoch 4/50
#
# Epoch 00004: val_dice did not improve from 0.38800
# 4/4 - 12s - loss: 1.6770 - iou: 0.4248 - dice: 0.5961 - val_loss: 1.8856 - val_iou: 0.2284 - val_dice: 0.3719
# Epoch 5/50
#
# Epoch 00005: val_dice did not improve from 0.38800
# 4/4 - 12s - loss: 1.6064 - iou: 0.4715 - dice: 0.6407 - val_loss: 1.8797 - val_iou: 0.2115 - val_dice: 0.3491
# Epoch 6/50
#
# Epoch 00006: val_dice did not improve from 0.38800
# 4/4 - 12s - loss: 1.5469 - iou: 0.5038 - dice: 0.6700 - val_loss: 1.8501 - val_iou: 0.2093 - val_dice: 0.3462
# Epoch 7/50
#
# Epoch 00007: val_dice did not improve from 0.38800
# 4/4 - 12s - loss: 1.4898 - iou: 0.5304 - dice: 0.6931 - val_loss: 1.8140 - val_iou: 0.2094 - val_dice: 0.3462
# Epoch 8/50
#
# Epoch 00008: val_dice did not improve from 0.38800
# 4/4 - 12s - loss: 1.4317 - iou: 0.5556 - dice: 0.7143 - val_loss: 1.7756 - val_iou: 0.2094 - val_dice: 0.3463
# Epoch 9/50
#
# Epoch 00009: val_dice did not improve from 0.38800
# 4/4 - 12s - loss: 1.3754 - iou: 0.5768 - dice: 0.7316 - val_loss: 1.7322 - val_iou: 0.2122 - val_dice: 0.3500
# Epoch 10/50
#
# Epoch 00010: val_dice did not improve from 0.38800
# 4/4 - 12s - loss: 1.3185 - iou: 0.5986 - dice: 0.7488 - val_loss: 1.6862 - val_iou: 0.2169 - val_dice: 0.3565
# Epoch 11/50
#
# Epoch 00011: val_dice did not improve from 0.38800
# 4/4 - 12s - loss: 1.2641 - iou: 0.6180 - dice: 0.7639 - val_loss: 1.6427 - val_iou: 0.2202 - val_dice: 0.3610
# Epoch 12/50
#
# Epoch 00012: val_dice improved from 0.38800 to 0.46685, saving model to ./model_1.h5
# 4/4 - 13s - loss: 1.2110 - iou: 0.6369 - dice: 0.7782 - val_loss: 1.4985 - val_iou: 0.3045 - val_dice: 0.4669
# Epoch 13/50
#
# Epoch 00013: val_dice improved from 0.46685 to 0.53329, saving model to ./model_1.h5
# 4/4 - 14s - loss: 1.1595 - iou: 0.6553 - dice: 0.7917 - val_loss: 1.3945 - val_iou: 0.3636 - val_dice: 0.5333
# Epoch 14/50
#
# Epoch 00014: val_dice did not improve from 0.53329
# 4/4 - 12s - loss: 1.1088 - iou: 0.6738 - dice: 0.8051 - val_loss: 1.7490 - val_iou: 0.0765 - val_dice: 0.1421
# Epoch 15/50
#
# Epoch 00015: val_dice did not improve from 0.53329
# 4/4 - 12s - loss: 1.0648 - iou: 0.6850 - dice: 0.8130 - val_loss: 1.8516 - val_iou: 0.0022 - val_dice: 0.0043
# Epoch 16/50
#
# Epoch 00016: val_dice did not improve from 0.53329
# 4/4 - 12s - loss: 1.0181 - iou: 0.7022 - dice: 0.8250 - val_loss: 1.3494 - val_iou: 0.3097 - val_dice: 0.4729
# Epoch 17/50
#
# Epoch 00017: val_dice did not improve from 0.53329
# 4/4 - 12s - loss: 0.9745 - iou: 0.7175 - dice: 0.8355 - val_loss: 1.3390 - val_iou: 0.2911 - val_dice: 0.4509
# Epoch 18/50
#
# Epoch 00018: val_dice did not improve from 0.53329
# 4/4 - 12s - loss: 0.9343 - iou: 0.7296 - dice: 0.8437 - val_loss: 1.3657 - val_iou: 0.2443 - val_dice: 0.3927
# Epoch 19/50
#
# Epoch 00019: val_dice did not improve from 0.53329
# 4/4 - 12s - loss: 0.8936 - iou: 0.7441 - dice: 0.8533 - val_loss: 1.6882 - val_iou: 0.0202 - val_dice: 0.0396
# Epoch 20/50
#
# Epoch 00020: val_dice did not improve from 0.53329
# 4/4 - 12s - loss: 0.8549 - iou: 0.7569 - dice: 0.8616 - val_loss: 1.6945 - val_iou: 0.0018 - val_dice: 0.0035
# Epoch 21/50
#
# Epoch 00021: val_dice did not improve from 0.53329
# 4/4 - 12s - loss: 0.8220 - iou: 0.7626 - dice: 0.8653 - val_loss: 1.6660 - val_iou: 0.0019 - val_dice: 0.0037
# Epoch 22/50
#
# Epoch 00022: val_dice did not improve from 0.53329
# 4/4 - 12s - loss: 0.7862 - iou: 0.7751 - dice: 0.8733 - val_loss: 1.6388 - val_iou: 0.0020 - val_dice: 0.0039
# Epoch 23/50
#
# Epoch 00023: val_dice did not improve from 0.53329
# 4/4 - 12s - loss: 0.7542 - iou: 0.7837 - dice: 0.8787 - val_loss: 1.6128 - val_iou: 0.0020 - val_dice: 0.0040
# Epoch 24/50
#
# Epoch 00024: val_dice did not improve from 0.53329
# 4/4 - 12s - loss: 0.7232 - iou: 0.7927 - dice: 0.8843 - val_loss: 1.5273 - val_iou: 0.0336 - val_dice: 0.0649
# Epoch 25/50
#
# Epoch 00025: val_dice did not improve from 0.53329
# 4/4 - 12s - loss: 0.6950 - iou: 0.7993 - dice: 0.8885 - val_loss: 1.5648 - val_iou: 0.0023 - val_dice: 0.0044
# Epoch 26/50
#
# Epoch 00026: val_dice did not improve from 0.53329
# 4/4 - 12s - loss: 0.6684 - iou: 0.8060 - dice: 0.8926 - val_loss: 1.5040 - val_iou: 0.0222 - val_dice: 0.0434
# Epoch 27/50
#
# Epoch 00027: val_dice did not improve from 0.53329
# 4/4 - 12s - loss: 0.6385 - iou: 0.8199 - dice: 0.9010 - val_loss: 1.4920 - val_iou: 0.0177 - val_dice: 0.0347
# Epoch 28/50
#
# Epoch 00028: val_dice did not improve from 0.53329
# 4/4 - 12s - loss: 0.6123 - iou: 0.8298 - dice: 0.9070 - val_loss: 1.5011 - val_iou: 0.0030 - val_dice: 0.0060
# Epoch 29/50
#
# Epoch 00029: val_dice did not improve from 0.53329
# 4/4 - 12s - loss: 0.5931 - iou: 0.8295 - dice: 0.9068 - val_loss: 1.4675 - val_iou: 0.0105 - val_dice: 0.0207
# Epoch 30/50
#
# Epoch 00030: val_dice did not improve from 0.53329
# 4/4 - 12s - loss: 0.5735 - iou: 0.8311 - dice: 0.9078 - val_loss: 1.4475 - val_iou: 0.0113 - val_dice: 0.0224
# Epoch 31/50
#
# Epoch 00031: val_dice improved from 0.53329 to 0.61501, saving model to ./model_1.h5
# 4/4 - 13s - loss: 0.5504 - iou: 0.8395 - dice: 0.9127 - val_loss: 0.8372 - val_iou: 0.4441 - val_dice: 0.6150
# Epoch 32/50
#
# Epoch 00032: val_dice did not improve from 0.61501
# 4/4 - 12s - loss: 0.5286 - iou: 0.8470 - dice: 0.9172 - val_loss: 1.3663 - val_iou: 0.0357 - val_dice: 0.0689
# Epoch 33/50
#
# Epoch 00033: val_dice did not improve from 0.61501
# 4/4 - 12s - loss: 0.5112 - iou: 0.8481 - dice: 0.9178 - val_loss: 1.3748 - val_iou: 0.0225 - val_dice: 0.0440
# Epoch 34/50
#
# Epoch 00034: val_dice did not improve from 0.61501
# 4/4 - 12s - loss: 0.4931 - iou: 0.8514 - dice: 0.9197 - val_loss: 1.1932 - val_iou: 0.1174 - val_dice: 0.2100
# Epoch 35/50
#
# Epoch 00035: val_dice did not improve from 0.61501
# 4/4 - 12s - loss: 0.4760 - iou: 0.8547 - dice: 0.9216 - val_loss: 0.9665 - val_iou: 0.2676 - val_dice: 0.4222
# Epoch 36/50
#
# Epoch 00036: val_dice did not improve from 0.61501
# 4/4 - 12s - loss: 0.4577 - iou: 0.8618 - dice: 0.9258 - val_loss: 0.9681 - val_iou: 0.2554 - val_dice: 0.4068
# Epoch 37/50
#
# Epoch 00037: val_dice did not improve from 0.61501
# 4/4 - 12s - loss: 0.4420 - iou: 0.8654 - dice: 0.9278 - val_loss: 1.3287 - val_iou: 0.0166 - val_dice: 0.0327
# Epoch 38/50
#
# Epoch 00038: val_dice did not improve from 0.61501
# 4/4 - 12s - loss: 0.4247 - iou: 0.8724 - dice: 0.9319 - val_loss: 1.3372 - val_iou: 0.0057 - val_dice: 0.0113
# Epoch 39/50
#
# Epoch 00039: val_dice did not improve from 0.61501
# 4/4 - 12s - loss: 0.4107 - iou: 0.8744 - dice: 0.9330 - val_loss: 1.3242 - val_iou: 0.0060 - val_dice: 0.0118
# Epoch 40/50
#
# Epoch 00040: val_dice did not improve from 0.61501
# 4/4 - 12s - loss: 0.3970 - iou: 0.8772 - dice: 0.9346 - val_loss: 1.3120 - val_iou: 0.0062 - val_dice: 0.0122
# Epoch 00040: early stopping

# %%
K.clear_session()

model = load_model('./model_1.h5', custom_objects={'dice_loss': utils.dice_loss,'iou': utils.iou, 'dice': utils.dice})

print('Metrics: ', model.metrics_names)  
l,i,d = model.evaluate(train_generator, verbose=1, sample_weight=None, steps=len(x_coord_train)//4)
print('train: ',l,i,d)

l,i,d = model.evaluate(val_generator, verbose=1, sample_weight=None, steps=len(x_coord_dev))
print('val: ',l,i,d)

l,i,d = model.evaluate(dev_test_generator(ipath_test,cpath_test,img_id_test,tile_id_test,y_coord_test,x_coord_test, 1), batch_size = 1, verbose=1, sample_weight=None, steps=len(x_coord_test))
print('test: ',l,i,d)

   
K.clear_session()
del model
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0606 19:02:44.043192 109064 deprecation.py:506] From c:\python36\lib\site-packages\tensorflow\python\ops\init_ops.py:97: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0606 19:02:44.043192 109064 deprecation.py:506] From c:\python36\lib\site-packages\tensorflow\python\ops\init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0606 19:02:44.043192 109064 deprecation.py:506] From c:\python36\lib\site-packages\tensorflow\python\ops\init_ops.py:97: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Metrics:  ['loss', 'iou', 'dice']
# 8/8 [==============================] - 4s 490ms/step - loss: 0.8417 - iou: 0.4394 - dice: 0.6105
# train:  0.8416581153869629 0.4394036 0.6105198
# 11/11 [==============================] - 5s 421ms/step - loss: 0.8372 - iou: 0.4441 - dice: 0.6150
# val:  0.8371680974960327 0.4440691 0.6150098
# 11/11 [==============================] - 5s 422ms/step - loss: 0.7846 - iou: 0.5011 - dice: 0.6676
# test:  0.7845747470855713 0.5010604 0.6676031

# %%
folder = "./images"
mpath = "./model_1.h5"
flist = utils.get_all_images(folder, "jpg")
predict.predict_all_images(flist,mpath,4)
# Out:
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 65426, 1: 110
# 0: 65426, 1: 110
# image 1 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 65536, 1: 0
# 0: 65536, 1: 0
# image 2 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 65347, 1: 189
# 0: 65347, 1: 189
# image 3 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 51533, 1: 14003
# 0: 51533, 1: 14003
# image 4 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 56348, 1: 9188
# 0: 56348, 1: 9188
# image 5 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 54834, 1: 10702
# 0: 54834, 1: 10702
# image 6 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 58045, 1: 7491
# 0: 58045, 1: 7491
# image 7 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 51436, 1: 14100
# 0: 51436, 1: 14100
# image 8 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 65536, 1: 0
# 0: 65536, 1: 0
# image 9 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 65536, 1: 0
# 0: 65536, 1: 0
# image 10 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 52332, 1: 13204
# 0: 52332, 1: 13204
# image 11 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 54301, 1: 11235
# 0: 54301, 1: 11235
# image 12 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 62220, 1: 3316
# 0: 62220, 1: 3316
# image 13 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 58030, 1: 7506
# 0: 58030, 1: 7506
# image 14 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 53535, 1: 12001
# 0: 53535, 1: 12001
# image 15 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 45165, 1: 20371
# 0: 45165, 1: 20371
# image 16 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 63037, 1: 2499
# 0: 63037, 1: 2499
# image 17 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 54411, 1: 11125
# 0: 54411, 1: 11125
# image 18 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 53225, 1: 12311
# 0: 53225, 1: 12311
# image 19 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 44783, 1: 20753
# 0: 44783, 1: 20753
# image 20 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 64601, 1: 935
# 0: 64601, 1: 935
# image 21 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 53347, 1: 12189
# 0: 53347, 1: 12189
# image 22 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 53200, 1: 12336
# 0: 53200, 1: 12336
# image 23 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 43435, 1: 22101
# 0: 43435, 1: 22101
# image 24 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 55167, 1: 10369
# 0: 55167, 1: 10369
# image 25 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 54813, 1: 10723
# 0: 54813, 1: 10723
# image 26 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 53762, 1: 11774
# 0: 53762, 1: 11774
# image 27 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 48651, 1: 16885
# 0: 48651, 1: 16885
# image 28 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 52278, 1: 13258
# 0: 52278, 1: 13258
# image 29 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 60338, 1: 5198
# 0: 60338, 1: 5198
# image 30 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 64035, 1: 1501
# 0: 64035, 1: 1501
# image 31 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 60704, 1: 4832
# 0: 60704, 1: 4832
# image 32 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 65536, 1: 0
# 0: 65536, 1: 0
# image 33 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 64022, 1: 1514
# 0: 64022, 1: 1514
# image 34 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 64664, 1: 872
# 0: 64664, 1: 872
# image 35 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 64855, 1: 681
# 0: 64855, 1: 681
# image 36 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 64778, 1: 758
# 0: 64778, 1: 758
# image 37 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 51380, 1: 14156
# 0: 51380, 1: 14156
# image 38 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 53584, 1: 11952
# 0: 53584, 1: 11952
# image 39 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 64379, 1: 1157
# 0: 64379, 1: 1157
# image 40 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 60144, 1: 5392
# 0: 60144, 1: 5392
# image 41 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 57734, 1: 7802
# 0: 57734, 1: 7802
# image 42 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 54684, 1: 10852
# 0: 54684, 1: 10852
# image 43 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 51468, 1: 14068
# 0: 51468, 1: 14068
# image 44 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 55359, 1: 10177
# 0: 55359, 1: 10177
# image 45 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 56331, 1: 9205
# 0: 56331, 1: 9205
# image 46 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 54458, 1: 11078
# 0: 54458, 1: 11078
# image 47 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 45089, 1: 20447
# 0: 45089, 1: 20447
# image 48 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 56259, 1: 9277
# 0: 56259, 1: 9277
# image 49 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 52624, 1: 12912
# 0: 52624, 1: 12912
# image 50 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 61640, 1: 3896
# 0: 61640, 1: 3896
# image 51 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 62026, 1: 3510
# 0: 62026, 1: 3510
# image 52 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 65087, 1: 449
# 0: 65087, 1: 449
# image 53 saved
# predicting
# (256, 256)
# predicting
# predicting
# predicting
# 0: 57030, 1: 8506
# 0: 57030, 1: 8506
# image 54 saved
